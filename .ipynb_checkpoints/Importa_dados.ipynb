# %%
import numpy as np
import matplotlib.pyplot as plt
from math import *
from scipy.integrate import odeint
import pandas

colunas = ['t', 'x', 'y', 'vx', 'vy']
dados = pandas.read_csv('experimento.csv', names =  colunas)

#dados do experimento
te = dados.t.tolist()
xe = dados.x.tolist()
ye = dados.y.tolist()
vxe = dados.vx.tolist()
vye = dados.vy.tolist()

plt.title("Trajetória do pêndulo")
plt.xlabel("x (m)")
plt.ylabel("y (m)")
plt.plot(xe, ye, 'ro', label = "Experimento")
plt.axis('equal')
plt.show()
